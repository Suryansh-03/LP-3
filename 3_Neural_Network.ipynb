# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
sns.set()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dataset = pd.read_csv('/content/drive/MyDrive/LP3 BE/Assignment No.3/Churn_Modelling.csv', index_col = 'RowNumber')
dataset.head()
# Out:
#            CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# RowNumber
# 1            15634602  Hargrave          619    France  Female   42       2
# 2            15647311      Hill          608     Spain  Female   41       1
# 3            15619304      Onio          502    France  Female   42       8
# 4            15701354      Boni          699    France  Female   39       1
# 5            15737888  Mitchell          850     Spain  Female   43       2
#
#              Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# RowNumber
# 1               0.00              1          1               1
# 2           83807.86              1          0               1
# 3          159660.80              3          1               0
# 4               0.00              2          0               0
# 5          125510.82              1          1               1
#
#            EstimatedSalary  Exited
# RowNumber
# 1                101348.88       1
# 2                112542.58       0
# 3                113931.57       1
# 4                 93826.63       0
# 5                 79084.10       0

# %%
#Customer ID and Surname would not be relevant as features
X_columns = dataset.columns.tolist()[2:12]
Y_columns = dataset.columns.tolist()[-1:]
print(X_columns)
print(Y_columns)
# Out:
# ['CreditScore', 'Geography', 'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary']
# ['Exited']

# %%
X = dataset[X_columns].values
Y = dataset[Y_columns].values

# %%
#We need to encode categorical variables such as geography and gender
from sklearn.preprocessing import LabelEncoder
X_column_transformer = LabelEncoder()
X[:, 1] = X_column_transformer.fit_transform(X[:, 1])

# %%
#Lets Encode gender now
X[:, 2] = X_column_transformer.fit_transform(X[:, 2])

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

pipeline = Pipeline(
    [
        ('Categorizer', ColumnTransformer(
            [
                ("Gender Label Encoder", OneHotEncoder(categories = 'auto', drop = 'first'), [2]),
                ("Geography Label Encoder", OneHotEncoder(categories = 'auto', drop = 'first'), [1])
            ],
            remainder = 'passthrough', n_jobs = 1)),
        ('Normalizer', StandardScaler())
    ]
)

# %%
#Standardize the features
X = pipeline.fit_transform(X)

# %%
#Spilt the data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 0)

# %%
#Let us create the Neural Network
from keras.models import Sequential
from keras.layers import Dense, Dropout

# %%
#Initialize ANN
classifier = Sequential()

# %%
#Add input layer and hidden layer
classifier.add(Dense(6, activation = 'relu', input_shape = (X_train.shape[1], )))
classifier.add(Dropout(rate = 0.1))

# %%
#Add second layer
classifier.add(Dense(6, activation = 'relu'))
classifier.add(Dropout(rate = 0.1))

# %%
#Add output layer
classifier.add(Dense(1, activation = 'sigmoid'))

# %%
#Let us take a look at our network
classifier.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 6)                 72
#
#  dropout (Dropout)           (None, 6)                 0
#
#  dense_1 (Dense)             (None, 6)                 42
#
#  dropout_1 (Dropout)         (None, 6)                 0
#
#  dense_2 (Dense)             (None, 1)                 7
#
# =================================================================
# Total params: 121 (484.00 Byte)
# Trainable params: 121 (484.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
#Optimize the weights
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
#Fitting the Neural Network
history = classifier.fit(X_train, y_train, batch_size = 32, epochs = 200, validation_split = 0.1, verbose = 2)
# Out:
# Epoch 1/200
# 225/225 - 2s - loss: 0.5827 - accuracy: 0.7572 - val_loss: 0.5199 - val_accuracy: 0.7950 - 2s/epoch - 9ms/step
# Epoch 2/200
# 225/225 - 0s - loss: 0.5016 - accuracy: 0.7961 - val_loss: 0.4781 - val_accuracy: 0.7950 - 252ms/epoch - 1ms/step
# Epoch 3/200
# 225/225 - 0s - loss: 0.4740 - accuracy: 0.7962 - val_loss: 0.4597 - val_accuracy: 0.7950 - 295ms/epoch - 1ms/step
# Epoch 4/200
# 225/225 - 0s - loss: 0.4639 - accuracy: 0.7960 - val_loss: 0.4479 - val_accuracy: 0.7950 - 291ms/epoch - 1ms/step
# Epoch 5/200
# 225/225 - 0s - loss: 0.4562 - accuracy: 0.7961 - val_loss: 0.4405 - val_accuracy: 0.7950 - 263ms/epoch - 1ms/step
# Epoch 6/200
# 225/225 - 0s - loss: 0.4517 - accuracy: 0.7961 - val_loss: 0.4341 - val_accuracy: 0.7950 - 295ms/epoch - 1ms/step
# Epoch 7/200
# 225/225 - 0s - loss: 0.4474 - accuracy: 0.7960 - val_loss: 0.4301 - val_accuracy: 0.7950 - 261ms/epoch - 1ms/step
# Epoch 8/200
# 225/225 - 0s - loss: 0.4444 - accuracy: 0.7961 - val_loss: 0.4275 - val_accuracy: 0.7950 - 253ms/epoch - 1ms/step
# Epoch 9/200
# 225/225 - 0s - loss: 0.4408 - accuracy: 0.7961 - val_loss: 0.4254 - val_accuracy: 0.7950 - 244ms/epoch - 1ms/step
# Epoch 10/200
# 225/225 - 0s - loss: 0.4424 - accuracy: 0.7961 - val_loss: 0.4235 - val_accuracy: 0.7950 - 291ms/epoch - 1ms/step
# Epoch 11/200
# 225/225 - 0s - loss: 0.4427 - accuracy: 0.7961 - val_loss: 0.4227 - val_accuracy: 0.7950 - 261ms/epoch - 1ms/step
# Epoch 12/200
# 225/225 - 0s - loss: 0.4416 - accuracy: 0.7961 - val_loss: 0.4223 - val_accuracy: 0.7950 - 251ms/epoch - 1ms/step
# Epoch 13/200
# 225/225 - 0s - loss: 0.4375 - accuracy: 0.7961 - val_loss: 0.4208 - val_accuracy: 0.7950 - 251ms/epoch - 1ms/step
# Epoch 14/200
# 225/225 - 0s - loss: 0.4393 - accuracy: 0.7960 - val_loss: 0.4199 - val_accuracy: 0.7950 - 298ms/epoch - 1ms/step
# Epoch 15/200
# 225/225 - 0s - loss: 0.4387 - accuracy: 0.7961 - val_loss: 0.4195 - val_accuracy: 0.7950 - 268ms/epoch - 1ms/step
# Epoch 16/200
# 225/225 - 0s - loss: 0.4365 - accuracy: 0.7961 - val_loss: 0.4183 - val_accuracy: 0.7950 - 250ms/epoch - 1ms/step
# Epoch 17/200
# 225/225 - 0s - loss: 0.4365 - accuracy: 0.7961 - val_loss: 0.4175 - val_accuracy: 0.7950 - 239ms/epoch - 1ms/step
# Epoch 18/200
# 225/225 - 0s - loss: 0.4370 - accuracy: 0.7962 - val_loss: 0.4174 - val_accuracy: 0.7950 - 254ms/epoch - 1ms/step
# Epoch 19/200
# 225/225 - 0s - loss: 0.4340 - accuracy: 0.7961 - val_loss: 0.4164 - val_accuracy: 0.7950 - 256ms/epoch - 1ms/step
# Epoch 20/200
# 225/225 - 0s - loss: 0.4347 - accuracy: 0.7960 - val_loss: 0.4152 - val_accuracy: 0.7950 - 284ms/epoch - 1ms/step
# Epoch 21/200
# 225/225 - 0s - loss: 0.4328 - accuracy: 0.7961 - val_loss: 0.4146 - val_accuracy: 0.7950 - 241ms/epoch - 1ms/step
# Epoch 22/200
# 225/225 - 0s - loss: 0.4349 - accuracy: 0.7961 - val_loss: 0.4147 - val_accuracy: 0.7950 - 262ms/epoch - 1ms/step
# Epoch 23/200
# 225/225 - 0s - loss: 0.4335 - accuracy: 0.7961 - val_loss: 0.4122 - val_accuracy: 0.7950 - 269ms/epoch - 1ms/step
# Epoch 24/200
# 225/225 - 0s - loss: 0.4361 - accuracy: 0.7961 - val_loss: 0.4123 - val_accuracy: 0.7950 - 306ms/epoch - 1ms/step
# Epoch 25/200
# 225/225 - 0s - loss: 0.4318 - accuracy: 0.7961 - val_loss: 0.4105 - val_accuracy: 0.7950 - 356ms/epoch - 2ms/step
# Epoch 26/200
# 225/225 - 0s - loss: 0.4323 - accuracy: 0.7961 - val_loss: 0.4108 - val_accuracy: 0.7950 - 329ms/epoch - 1ms/step
# Epoch 27/200
# 225/225 - 0s - loss: 0.4356 - accuracy: 0.7961 - val_loss: 0.4095 - val_accuracy: 0.7950 - 359ms/epoch - 2ms/step
# Epoch 28/200
# 225/225 - 0s - loss: 0.4330 - accuracy: 0.7961 - val_loss: 0.4082 - val_accuracy: 0.7950 - 331ms/epoch - 1ms/step
# Epoch 29/200
# 225/225 - 0s - loss: 0.4321 - accuracy: 0.8042 - val_loss: 0.4064 - val_accuracy: 0.8238 - 328ms/epoch - 1ms/step
# Epoch 30/200
# 225/225 - 0s - loss: 0.4278 - accuracy: 0.8151 - val_loss: 0.4043 - val_accuracy: 0.8288 - 303ms/epoch - 1ms/step
# Epoch 31/200
# 225/225 - 0s - loss: 0.4285 - accuracy: 0.8171 - val_loss: 0.4028 - val_accuracy: 0.8313 - 320ms/epoch - 1ms/step
# Epoch 32/200
# 225/225 - 0s - loss: 0.4286 - accuracy: 0.8256 - val_loss: 0.4002 - val_accuracy: 0.8325 - 353ms/epoch - 2ms/step
# Epoch 33/200
# 225/225 - 0s - loss: 0.4240 - accuracy: 0.8214 - val_loss: 0.3992 - val_accuracy: 0.8325 - 263ms/epoch - 1ms/step
# Epoch 34/200
# 225/225 - 0s - loss: 0.4274 - accuracy: 0.8240 - val_loss: 0.3990 - val_accuracy: 0.8350 - 263ms/epoch - 1ms/step
# Epoch 35/200
# 225/225 - 0s - loss: 0.4277 - accuracy: 0.8219 - val_loss: 0.3985 - val_accuracy: 0.8375 - 420ms/epoch - 2ms/step
# Epoch 36/200
# 225/225 - 1s - loss: 0.4212 - accuracy: 0.8232 - val_loss: 0.3972 - val_accuracy: 0.8363 - 667ms/epoch - 3ms/step
# Epoch 37/200
# 225/225 - 1s - loss: 0.4286 - accuracy: 0.8158 - val_loss: 0.3976 - val_accuracy: 0.8350 - 733ms/epoch - 3ms/step
# Epoch 38/200
# 225/225 - 1s - loss: 0.4254 - accuracy: 0.8215 - val_loss: 0.3966 - val_accuracy: 0.8375 - 700ms/epoch - 3ms/step
# Epoch 39/200
# 225/225 - 1s - loss: 0.4265 - accuracy: 0.8235 - val_loss: 0.3961 - val_accuracy: 0.8350 - 740ms/epoch - 3ms/step
# Epoch 40/200
# 225/225 - 1s - loss: 0.4250 - accuracy: 0.8221 - val_loss: 0.3954 - val_accuracy: 0.8400 - 587ms/epoch - 3ms/step
# Epoch 41/200
# 225/225 - 1s - loss: 0.4216 - accuracy: 0.8200 - val_loss: 0.3954 - val_accuracy: 0.8350 - 549ms/epoch - 2ms/step
# Epoch 42/200
# 225/225 - 1s - loss: 0.4211 - accuracy: 0.8225 - val_loss: 0.3944 - val_accuracy: 0.8325 - 555ms/epoch - 2ms/step
# Epoch 43/200
# 225/225 - 0s - loss: 0.4205 - accuracy: 0.8243 - val_loss: 0.3934 - val_accuracy: 0.8338 - 428ms/epoch - 2ms/step
# Epoch 44/200
# 225/225 - 0s - loss: 0.4220 - accuracy: 0.8242 - val_loss: 0.3926 - val_accuracy: 0.8350 - 451ms/epoch - 2ms/step
# Epoch 45/200
# 225/225 - 0s - loss: 0.4197 - accuracy: 0.8247 - val_loss: 0.3926 - val_accuracy: 0.8350 - 473ms/epoch - 2ms/step
# Epoch 46/200
# 225/225 - 0s - loss: 0.4187 - accuracy: 0.8232 - val_loss: 0.3909 - val_accuracy: 0.8363 - 396ms/epoch - 2ms/step
# Epoch 47/200
# 225/225 - 0s - loss: 0.4209 - accuracy: 0.8238 - val_loss: 0.3907 - val_accuracy: 0.8363 - 380ms/epoch - 2ms/step
# Epoch 48/200
# 225/225 - 0s - loss: 0.4194 - accuracy: 0.8265 - val_loss: 0.3898 - val_accuracy: 0.8375 - 377ms/epoch - 2ms/step
# Epoch 49/200
# 225/225 - 1s - loss: 0.4182 - accuracy: 0.8253 - val_loss: 0.3904 - val_accuracy: 0.8388 - 769ms/epoch - 3ms/step
# Epoch 50/200
# 225/225 - 0s - loss: 0.4218 - accuracy: 0.8242 - val_loss: 0.3899 - val_accuracy: 0.8400 - 464ms/epoch - 2ms/step
# Epoch 51/200
# 225/225 - 0s - loss: 0.4223 - accuracy: 0.8228 - val_loss: 0.3898 - val_accuracy: 0.8413 - 364ms/epoch - 2ms/step
# Epoch 52/200
# 225/225 - 1s - loss: 0.4217 - accuracy: 0.8236 - val_loss: 0.3892 - val_accuracy: 0.8375 - 623ms/epoch - 3ms/step
# Epoch 53/200
# 225/225 - 1s - loss: 0.4178 - accuracy: 0.8251 - val_loss: 0.3893 - val_accuracy: 0.8388 - 698ms/epoch - 3ms/step
# Epoch 54/200
# 225/225 - 1s - loss: 0.4186 - accuracy: 0.8242 - val_loss: 0.3884 - val_accuracy: 0.8388 - 810ms/epoch - 4ms/step
# Epoch 55/200
# 225/225 - 1s - loss: 0.4205 - accuracy: 0.8218 - val_loss: 0.3900 - val_accuracy: 0.8388 - 806ms/epoch - 4ms/step
# Epoch 56/200
# 225/225 - 1s - loss: 0.4183 - accuracy: 0.8253 - val_loss: 0.3884 - val_accuracy: 0.8388 - 674ms/epoch - 3ms/step
# Epoch 57/200
# 225/225 - 1s - loss: 0.4191 - accuracy: 0.8271 - val_loss: 0.3891 - val_accuracy: 0.8388 - 519ms/epoch - 2ms/step
# Epoch 58/200
# 225/225 - 0s - loss: 0.4198 - accuracy: 0.8243 - val_loss: 0.3888 - val_accuracy: 0.8375 - 415ms/epoch - 2ms/step
# Epoch 59/200
# 225/225 - 0s - loss: 0.4173 - accuracy: 0.8267 - val_loss: 0.3888 - val_accuracy: 0.8375 - 239ms/epoch - 1ms/step
# Epoch 60/200
# 225/225 - 0s - loss: 0.4213 - accuracy: 0.8242 - val_loss: 0.3878 - val_accuracy: 0.8363 - 236ms/epoch - 1ms/step
# Epoch 61/200
# 225/225 - 0s - loss: 0.4176 - accuracy: 0.8251 - val_loss: 0.3874 - val_accuracy: 0.8375 - 241ms/epoch - 1ms/step
# Epoch 62/200
# 225/225 - 0s - loss: 0.4177 - accuracy: 0.8272 - val_loss: 0.3869 - val_accuracy: 0.8363 - 287ms/epoch - 1ms/step
# Epoch 63/200
# 225/225 - 0s - loss: 0.4147 - accuracy: 0.8271 - val_loss: 0.3861 - val_accuracy: 0.8363 - 250ms/epoch - 1ms/step
# Epoch 64/200
# 225/225 - 0s - loss: 0.4111 - accuracy: 0.8294 - val_loss: 0.3864 - val_accuracy: 0.8375 - 238ms/epoch - 1ms/step
# Epoch 65/200
# 225/225 - 0s - loss: 0.4164 - accuracy: 0.8249 - val_loss: 0.3869 - val_accuracy: 0.8363 - 251ms/epoch - 1ms/step
# Epoch 66/200
# 225/225 - 0s - loss: 0.4144 - accuracy: 0.8281 - val_loss: 0.3859 - val_accuracy: 0.8413 - 292ms/epoch - 1ms/step
# Epoch 67/200
# 225/225 - 0s - loss: 0.4170 - accuracy: 0.8249 - val_loss: 0.3855 - val_accuracy: 0.8388 - 293ms/epoch - 1ms/step
# Epoch 68/200
# 225/225 - 0s - loss: 0.4170 - accuracy: 0.8253 - val_loss: 0.3863 - val_accuracy: 0.8388 - 282ms/epoch - 1ms/step
# Epoch 69/200
# 225/225 - 0s - loss: 0.4165 - accuracy: 0.8250 - val_loss: 0.3860 - val_accuracy: 0.8363 - 285ms/epoch - 1ms/step
# Epoch 70/200
# 225/225 - 0s - loss: 0.4156 - accuracy: 0.8278 - val_loss: 0.3866 - val_accuracy: 0.8388 - 244ms/epoch - 1ms/step
# Epoch 71/200
# 225/225 - 0s - loss: 0.4168 - accuracy: 0.8239 - val_loss: 0.3865 - val_accuracy: 0.8375 - 242ms/epoch - 1ms/step
# Epoch 72/200
# 225/225 - 0s - loss: 0.4143 - accuracy: 0.8289 - val_loss: 0.3865 - val_accuracy: 0.8388 - 242ms/epoch - 1ms/step
# Epoch 73/200
# 225/225 - 0s - loss: 0.4175 - accuracy: 0.8256 - val_loss: 0.3868 - val_accuracy: 0.8375 - 245ms/epoch - 1ms/step
# Epoch 74/200
# 225/225 - 0s - loss: 0.4163 - accuracy: 0.8271 - val_loss: 0.3862 - val_accuracy: 0.8375 - 243ms/epoch - 1ms/step
# Epoch 75/200
# 225/225 - 0s - loss: 0.4123 - accuracy: 0.8257 - val_loss: 0.3853 - val_accuracy: 0.8388 - 255ms/epoch - 1ms/step
# Epoch 76/200
# 225/225 - 0s - loss: 0.4145 - accuracy: 0.8274 - val_loss: 0.3860 - val_accuracy: 0.8400 - 261ms/epoch - 1ms/step
# Epoch 77/200
# 225/225 - 0s - loss: 0.4177 - accuracy: 0.8240 - val_loss: 0.3862 - val_accuracy: 0.8388 - 260ms/epoch - 1ms/step
# Epoch 78/200
# 225/225 - 0s - loss: 0.4167 - accuracy: 0.8286 - val_loss: 0.3870 - val_accuracy: 0.8413 - 292ms/epoch - 1ms/step
# Epoch 79/200
# 225/225 - 0s - loss: 0.4167 - accuracy: 0.8257 - val_loss: 0.3867 - val_accuracy: 0.8388 - 247ms/epoch - 1ms/step
# Epoch 80/200
# 225/225 - 0s - loss: 0.4130 - accuracy: 0.8313 - val_loss: 0.3855 - val_accuracy: 0.8388 - 253ms/epoch - 1ms/step
# Epoch 81/200
# 225/225 - 0s - loss: 0.4148 - accuracy: 0.8279 - val_loss: 0.3868 - val_accuracy: 0.8375 - 293ms/epoch - 1ms/step
# Epoch 82/200
# 225/225 - 0s - loss: 0.4153 - accuracy: 0.8275 - val_loss: 0.3861 - val_accuracy: 0.8388 - 293ms/epoch - 1ms/step
# Epoch 83/200
# 225/225 - 0s - loss: 0.4125 - accuracy: 0.8290 - val_loss: 0.3855 - val_accuracy: 0.8413 - 245ms/epoch - 1ms/step
# Epoch 84/200
# 225/225 - 0s - loss: 0.4133 - accuracy: 0.8290 - val_loss: 0.3850 - val_accuracy: 0.8438 - 252ms/epoch - 1ms/step
# Epoch 85/200
# 225/225 - 0s - loss: 0.4160 - accuracy: 0.8250 - val_loss: 0.3854 - val_accuracy: 0.8400 - 246ms/epoch - 1ms/step
# Epoch 86/200
# 225/225 - 0s - loss: 0.4155 - accuracy: 0.8261 - val_loss: 0.3852 - val_accuracy: 0.8400 - 275ms/epoch - 1ms/step
# Epoch 87/200
# 225/225 - 0s - loss: 0.4146 - accuracy: 0.8282 - val_loss: 0.3850 - val_accuracy: 0.8413 - 238ms/epoch - 1ms/step
# Epoch 88/200
# 225/225 - 0s - loss: 0.4133 - accuracy: 0.8289 - val_loss: 0.3859 - val_accuracy: 0.8413 - 245ms/epoch - 1ms/step
# Epoch 89/200
# 225/225 - 0s - loss: 0.4139 - accuracy: 0.8276 - val_loss: 0.3848 - val_accuracy: 0.8413 - 255ms/epoch - 1ms/step
# Epoch 90/200
# 225/225 - 0s - loss: 0.4160 - accuracy: 0.8261 - val_loss: 0.3868 - val_accuracy: 0.8425 - 280ms/epoch - 1ms/step
# Epoch 91/200
# 225/225 - 0s - loss: 0.4164 - accuracy: 0.8253 - val_loss: 0.3856 - val_accuracy: 0.8413 - 244ms/epoch - 1ms/step
# Epoch 92/200
# 225/225 - 0s - loss: 0.4122 - accuracy: 0.8288 - val_loss: 0.3846 - val_accuracy: 0.8400 - 320ms/epoch - 1ms/step
# Epoch 93/200
# 225/225 - 0s - loss: 0.4119 - accuracy: 0.8265 - val_loss: 0.3855 - val_accuracy: 0.8425 - 309ms/epoch - 1ms/step
# Epoch 94/200
# 225/225 - 0s - loss: 0.4131 - accuracy: 0.8265 - val_loss: 0.3861 - val_accuracy: 0.8413 - 362ms/epoch - 2ms/step
# Epoch 95/200
# 225/225 - 0s - loss: 0.4115 - accuracy: 0.8303 - val_loss: 0.3863 - val_accuracy: 0.8413 - 318ms/epoch - 1ms/step
# Epoch 96/200
# 225/225 - 0s - loss: 0.4168 - accuracy: 0.8249 - val_loss: 0.3867 - val_accuracy: 0.8413 - 316ms/epoch - 1ms/step
# Epoch 97/200
# 225/225 - 0s - loss: 0.4162 - accuracy: 0.8243 - val_loss: 0.3871 - val_accuracy: 0.8400 - 359ms/epoch - 2ms/step
# Epoch 98/200
# 225/225 - 0s - loss: 0.4148 - accuracy: 0.8253 - val_loss: 0.3878 - val_accuracy: 0.8400 - 357ms/epoch - 2ms/step
# Epoch 99/200
# 225/225 - 0s - loss: 0.4125 - accuracy: 0.8286 - val_loss: 0.3874 - val_accuracy: 0.8413 - 380ms/epoch - 2ms/step
# Epoch 100/200
# 225/225 - 0s - loss: 0.4132 - accuracy: 0.8289 - val_loss: 0.3858 - val_accuracy: 0.8425 - 285ms/epoch - 1ms/step
# Epoch 101/200
# 225/225 - 0s - loss: 0.4120 - accuracy: 0.8289 - val_loss: 0.3871 - val_accuracy: 0.8388 - 247ms/epoch - 1ms/step
# Epoch 102/200
# 225/225 - 0s - loss: 0.4122 - accuracy: 0.8275 - val_loss: 0.3858 - val_accuracy: 0.8388 - 254ms/epoch - 1ms/step
# Epoch 103/200
# 225/225 - 0s - loss: 0.4129 - accuracy: 0.8285 - val_loss: 0.3855 - val_accuracy: 0.8400 - 252ms/epoch - 1ms/step
# Epoch 104/200
# 225/225 - 0s - loss: 0.4143 - accuracy: 0.8256 - val_loss: 0.3854 - val_accuracy: 0.8400 - 252ms/epoch - 1ms/step
# Epoch 105/200
# 225/225 - 0s - loss: 0.4110 - accuracy: 0.8285 - val_loss: 0.3850 - val_accuracy: 0.8400 - 290ms/epoch - 1ms/step
# Epoch 106/200
# 225/225 - 0s - loss: 0.4157 - accuracy: 0.8272 - val_loss: 0.3859 - val_accuracy: 0.8425 - 292ms/epoch - 1ms/step
# Epoch 107/200
# 225/225 - 0s - loss: 0.4149 - accuracy: 0.8263 - val_loss: 0.3863 - val_accuracy: 0.8438 - 293ms/epoch - 1ms/step
# Epoch 108/200
# 225/225 - 0s - loss: 0.4164 - accuracy: 0.8251 - val_loss: 0.3857 - val_accuracy: 0.8400 - 246ms/epoch - 1ms/step
# Epoch 109/200
# 225/225 - 0s - loss: 0.4128 - accuracy: 0.8283 - val_loss: 0.3860 - val_accuracy: 0.8438 - 249ms/epoch - 1ms/step
# Epoch 110/200
# 225/225 - 0s - loss: 0.4129 - accuracy: 0.8297 - val_loss: 0.3856 - val_accuracy: 0.8425 - 263ms/epoch - 1ms/step
# Epoch 111/200
# 225/225 - 0s - loss: 0.4120 - accuracy: 0.8290 - val_loss: 0.3858 - val_accuracy: 0.8450 - 278ms/epoch - 1ms/step
# Epoch 112/200
# 225/225 - 0s - loss: 0.4107 - accuracy: 0.8292 - val_loss: 0.3845 - val_accuracy: 0.8462 - 295ms/epoch - 1ms/step
# Epoch 113/200
# 225/225 - 0s - loss: 0.4136 - accuracy: 0.8275 - val_loss: 0.3855 - val_accuracy: 0.8425 - 264ms/epoch - 1ms/step
# Epoch 114/200
# 225/225 - 0s - loss: 0.4112 - accuracy: 0.8293 - val_loss: 0.3862 - val_accuracy: 0.8425 - 249ms/epoch - 1ms/step
# Epoch 115/200
# 225/225 - 0s - loss: 0.4121 - accuracy: 0.8278 - val_loss: 0.3854 - val_accuracy: 0.8438 - 295ms/epoch - 1ms/step
# Epoch 116/200
# 225/225 - 0s - loss: 0.4126 - accuracy: 0.8317 - val_loss: 0.3859 - val_accuracy: 0.8425 - 286ms/epoch - 1ms/step
# Epoch 117/200
# 225/225 - 0s - loss: 0.4123 - accuracy: 0.8274 - val_loss: 0.3865 - val_accuracy: 0.8438 - 253ms/epoch - 1ms/step
# Epoch 118/200
# 225/225 - 0s - loss: 0.4114 - accuracy: 0.8296 - val_loss: 0.3853 - val_accuracy: 0.8425 - 245ms/epoch - 1ms/step
# Epoch 119/200
# 225/225 - 0s - loss: 0.4135 - accuracy: 0.8279 - val_loss: 0.3857 - val_accuracy: 0.8413 - 281ms/epoch - 1ms/step
# Epoch 120/200
# 225/225 - 0s - loss: 0.4160 - accuracy: 0.8276 - val_loss: 0.3856 - val_accuracy: 0.8425 - 242ms/epoch - 1ms/step
# Epoch 121/200
# 225/225 - 0s - loss: 0.4141 - accuracy: 0.8288 - val_loss: 0.3862 - val_accuracy: 0.8438 - 308ms/epoch - 1ms/step
# Epoch 122/200
# 225/225 - 0s - loss: 0.4097 - accuracy: 0.8290 - val_loss: 0.3853 - val_accuracy: 0.8438 - 243ms/epoch - 1ms/step
# Epoch 123/200
# 225/225 - 0s - loss: 0.4119 - accuracy: 0.8297 - val_loss: 0.3844 - val_accuracy: 0.8413 - 240ms/epoch - 1ms/step
# Epoch 124/200
# 225/225 - 0s - loss: 0.4128 - accuracy: 0.8297 - val_loss: 0.3864 - val_accuracy: 0.8425 - 295ms/epoch - 1ms/step
# Epoch 125/200
# 225/225 - 0s - loss: 0.4129 - accuracy: 0.8297 - val_loss: 0.3862 - val_accuracy: 0.8400 - 254ms/epoch - 1ms/step
# Epoch 126/200
# 225/225 - 0s - loss: 0.4113 - accuracy: 0.8290 - val_loss: 0.3862 - val_accuracy: 0.8425 - 248ms/epoch - 1ms/step
# Epoch 127/200
# 225/225 - 0s - loss: 0.4153 - accuracy: 0.8260 - val_loss: 0.3851 - val_accuracy: 0.8425 - 293ms/epoch - 1ms/step
# Epoch 128/200
# 225/225 - 0s - loss: 0.4118 - accuracy: 0.8296 - val_loss: 0.3844 - val_accuracy: 0.8413 - 292ms/epoch - 1ms/step
# Epoch 129/200
# 225/225 - 0s - loss: 0.4114 - accuracy: 0.8265 - val_loss: 0.3845 - val_accuracy: 0.8425 - 243ms/epoch - 1ms/step
# Epoch 130/200
# 225/225 - 0s - loss: 0.4140 - accuracy: 0.8286 - val_loss: 0.3847 - val_accuracy: 0.8413 - 245ms/epoch - 1ms/step
# Epoch 131/200
# 225/225 - 0s - loss: 0.4139 - accuracy: 0.8275 - val_loss: 0.3860 - val_accuracy: 0.8413 - 267ms/epoch - 1ms/step
# Epoch 132/200
# 225/225 - 0s - loss: 0.4148 - accuracy: 0.8268 - val_loss: 0.3868 - val_accuracy: 0.8413 - 253ms/epoch - 1ms/step
# Epoch 133/200
# 225/225 - 0s - loss: 0.4104 - accuracy: 0.8278 - val_loss: 0.3872 - val_accuracy: 0.8438 - 248ms/epoch - 1ms/step
# Epoch 134/200
# 225/225 - 0s - loss: 0.4141 - accuracy: 0.8265 - val_loss: 0.3870 - val_accuracy: 0.8438 - 248ms/epoch - 1ms/step
# Epoch 135/200
# 225/225 - 0s - loss: 0.4121 - accuracy: 0.8271 - val_loss: 0.3877 - val_accuracy: 0.8425 - 282ms/epoch - 1ms/step
# Epoch 136/200
# 225/225 - 0s - loss: 0.4125 - accuracy: 0.8307 - val_loss: 0.3868 - val_accuracy: 0.8425 - 254ms/epoch - 1ms/step
# Epoch 137/200
# 225/225 - 0s - loss: 0.4132 - accuracy: 0.8289 - val_loss: 0.3862 - val_accuracy: 0.8438 - 305ms/epoch - 1ms/step
# Epoch 138/200
# 225/225 - 0s - loss: 0.4102 - accuracy: 0.8326 - val_loss: 0.3865 - val_accuracy: 0.8438 - 348ms/epoch - 2ms/step
# Epoch 139/200
# 225/225 - 0s - loss: 0.4130 - accuracy: 0.8288 - val_loss: 0.3881 - val_accuracy: 0.8438 - 380ms/epoch - 2ms/step
# Epoch 140/200
# 225/225 - 0s - loss: 0.4093 - accuracy: 0.8314 - val_loss: 0.3863 - val_accuracy: 0.8413 - 339ms/epoch - 2ms/step
# Epoch 141/200
# 225/225 - 0s - loss: 0.4125 - accuracy: 0.8283 - val_loss: 0.3860 - val_accuracy: 0.8425 - 307ms/epoch - 1ms/step
# Epoch 142/200
# 225/225 - 0s - loss: 0.4161 - accuracy: 0.8271 - val_loss: 0.3862 - val_accuracy: 0.8425 - 352ms/epoch - 2ms/step
# Epoch 143/200
# 225/225 - 0s - loss: 0.4115 - accuracy: 0.8299 - val_loss: 0.3860 - val_accuracy: 0.8413 - 351ms/epoch - 2ms/step
# Epoch 144/200
# 225/225 - 0s - loss: 0.4124 - accuracy: 0.8283 - val_loss: 0.3876 - val_accuracy: 0.8438 - 364ms/epoch - 2ms/step
# Epoch 145/200
# 225/225 - 0s - loss: 0.4119 - accuracy: 0.8303 - val_loss: 0.3862 - val_accuracy: 0.8413 - 282ms/epoch - 1ms/step
# Epoch 146/200
# 225/225 - 0s - loss: 0.4103 - accuracy: 0.8299 - val_loss: 0.3860 - val_accuracy: 0.8413 - 236ms/epoch - 1ms/step
# Epoch 147/200
# 225/225 - 0s - loss: 0.4124 - accuracy: 0.8275 - val_loss: 0.3858 - val_accuracy: 0.8400 - 238ms/epoch - 1ms/step
# Epoch 148/200
# 225/225 - 0s - loss: 0.4136 - accuracy: 0.8288 - val_loss: 0.3863 - val_accuracy: 0.8425 - 247ms/epoch - 1ms/step
# Epoch 149/200
# 225/225 - 0s - loss: 0.4122 - accuracy: 0.8297 - val_loss: 0.3873 - val_accuracy: 0.8425 - 247ms/epoch - 1ms/step
# Epoch 150/200
# 225/225 - 0s - loss: 0.4129 - accuracy: 0.8290 - val_loss: 0.3868 - val_accuracy: 0.8438 - 281ms/epoch - 1ms/step
# Epoch 151/200
# 225/225 - 0s - loss: 0.4104 - accuracy: 0.8294 - val_loss: 0.3857 - val_accuracy: 0.8438 - 285ms/epoch - 1ms/step
# Epoch 152/200
# 225/225 - 0s - loss: 0.4131 - accuracy: 0.8304 - val_loss: 0.3880 - val_accuracy: 0.8438 - 241ms/epoch - 1ms/step
# Epoch 153/200
# 225/225 - 0s - loss: 0.4117 - accuracy: 0.8304 - val_loss: 0.3860 - val_accuracy: 0.8425 - 245ms/epoch - 1ms/step
# Epoch 154/200
# 225/225 - 0s - loss: 0.4128 - accuracy: 0.8304 - val_loss: 0.3868 - val_accuracy: 0.8413 - 249ms/epoch - 1ms/step
# Epoch 155/200
# 225/225 - 0s - loss: 0.4143 - accuracy: 0.8304 - val_loss: 0.3857 - val_accuracy: 0.8425 - 248ms/epoch - 1ms/step
# Epoch 156/200
# 225/225 - 0s - loss: 0.4106 - accuracy: 0.8339 - val_loss: 0.3885 - val_accuracy: 0.8413 - 245ms/epoch - 1ms/step
# Epoch 157/200
# 225/225 - 0s - loss: 0.4104 - accuracy: 0.8304 - val_loss: 0.3866 - val_accuracy: 0.8413 - 296ms/epoch - 1ms/step
# Epoch 158/200
# 225/225 - 0s - loss: 0.4137 - accuracy: 0.8275 - val_loss: 0.3872 - val_accuracy: 0.8400 - 255ms/epoch - 1ms/step
# Epoch 159/200
# 225/225 - 0s - loss: 0.4155 - accuracy: 0.8282 - val_loss: 0.3882 - val_accuracy: 0.8413 - 239ms/epoch - 1ms/step
# Epoch 160/200
# 225/225 - 0s - loss: 0.4134 - accuracy: 0.8294 - val_loss: 0.3871 - val_accuracy: 0.8413 - 249ms/epoch - 1ms/step
# Epoch 161/200
# 225/225 - 0s - loss: 0.4122 - accuracy: 0.8326 - val_loss: 0.3877 - val_accuracy: 0.8413 - 248ms/epoch - 1ms/step
# Epoch 162/200
# 225/225 - 0s - loss: 0.4139 - accuracy: 0.8293 - val_loss: 0.3879 - val_accuracy: 0.8413 - 244ms/epoch - 1ms/step
# Epoch 163/200
# 225/225 - 0s - loss: 0.4121 - accuracy: 0.8311 - val_loss: 0.3866 - val_accuracy: 0.8425 - 241ms/epoch - 1ms/step
# Epoch 164/200
# 225/225 - 0s - loss: 0.4144 - accuracy: 0.8288 - val_loss: 0.3879 - val_accuracy: 0.8413 - 250ms/epoch - 1ms/step
# Epoch 165/200
# 225/225 - 0s - loss: 0.4147 - accuracy: 0.8272 - val_loss: 0.3876 - val_accuracy: 0.8425 - 256ms/epoch - 1ms/step
# Epoch 166/200
# 225/225 - 0s - loss: 0.4134 - accuracy: 0.8283 - val_loss: 0.3872 - val_accuracy: 0.8438 - 245ms/epoch - 1ms/step
# Epoch 167/200
# 225/225 - 0s - loss: 0.4122 - accuracy: 0.8274 - val_loss: 0.3866 - val_accuracy: 0.8425 - 245ms/epoch - 1ms/step
# Epoch 168/200
# 225/225 - 0s - loss: 0.4136 - accuracy: 0.8278 - val_loss: 0.3874 - val_accuracy: 0.8413 - 246ms/epoch - 1ms/step
# Epoch 169/200
# 225/225 - 0s - loss: 0.4135 - accuracy: 0.8271 - val_loss: 0.3876 - val_accuracy: 0.8400 - 250ms/epoch - 1ms/step
# Epoch 170/200
# 225/225 - 0s - loss: 0.4137 - accuracy: 0.8306 - val_loss: 0.3888 - val_accuracy: 0.8413 - 251ms/epoch - 1ms/step
# Epoch 171/200
# 225/225 - 0s - loss: 0.4136 - accuracy: 0.8293 - val_loss: 0.3867 - val_accuracy: 0.8425 - 285ms/epoch - 1ms/step
# Epoch 172/200
# 225/225 - 0s - loss: 0.4113 - accuracy: 0.8308 - val_loss: 0.3867 - val_accuracy: 0.8400 - 233ms/epoch - 1ms/step
# Epoch 173/200
# 225/225 - 0s - loss: 0.4096 - accuracy: 0.8313 - val_loss: 0.3862 - val_accuracy: 0.8413 - 255ms/epoch - 1ms/step
# Epoch 174/200
# 225/225 - 0s - loss: 0.4144 - accuracy: 0.8276 - val_loss: 0.3869 - val_accuracy: 0.8413 - 248ms/epoch - 1ms/step
# Epoch 175/200
# 225/225 - 0s - loss: 0.4104 - accuracy: 0.8321 - val_loss: 0.3861 - val_accuracy: 0.8413 - 253ms/epoch - 1ms/step
# Epoch 176/200
# 225/225 - 0s - loss: 0.4109 - accuracy: 0.8300 - val_loss: 0.3877 - val_accuracy: 0.8413 - 288ms/epoch - 1ms/step
# Epoch 177/200
# 225/225 - 0s - loss: 0.4157 - accuracy: 0.8282 - val_loss: 0.3888 - val_accuracy: 0.8413 - 246ms/epoch - 1ms/step
# Epoch 178/200
# 225/225 - 0s - loss: 0.4125 - accuracy: 0.8274 - val_loss: 0.3877 - val_accuracy: 0.8413 - 272ms/epoch - 1ms/step
# Epoch 179/200
# 225/225 - 0s - loss: 0.4120 - accuracy: 0.8306 - val_loss: 0.3868 - val_accuracy: 0.8413 - 233ms/epoch - 1ms/step
# Epoch 180/200
# 225/225 - 0s - loss: 0.4130 - accuracy: 0.8294 - val_loss: 0.3866 - val_accuracy: 0.8388 - 251ms/epoch - 1ms/step
# Epoch 181/200
# 225/225 - 0s - loss: 0.4108 - accuracy: 0.8319 - val_loss: 0.3872 - val_accuracy: 0.8413 - 258ms/epoch - 1ms/step
# Epoch 182/200
# 225/225 - 0s - loss: 0.4130 - accuracy: 0.8321 - val_loss: 0.3862 - val_accuracy: 0.8388 - 239ms/epoch - 1ms/step
# Epoch 183/200
# 225/225 - 0s - loss: 0.4150 - accuracy: 0.8275 - val_loss: 0.3864 - val_accuracy: 0.8413 - 248ms/epoch - 1ms/step
# Epoch 184/200
# 225/225 - 0s - loss: 0.4146 - accuracy: 0.8275 - val_loss: 0.3869 - val_accuracy: 0.8400 - 345ms/epoch - 2ms/step
# Epoch 185/200
# 225/225 - 0s - loss: 0.4120 - accuracy: 0.8299 - val_loss: 0.3887 - val_accuracy: 0.8413 - 346ms/epoch - 2ms/step
# Epoch 186/200
# 225/225 - 0s - loss: 0.4126 - accuracy: 0.8290 - val_loss: 0.3861 - val_accuracy: 0.8400 - 328ms/epoch - 1ms/step
# Epoch 187/200
# 225/225 - 0s - loss: 0.4123 - accuracy: 0.8300 - val_loss: 0.3867 - val_accuracy: 0.8413 - 341ms/epoch - 2ms/step
# Epoch 188/200
# 225/225 - 0s - loss: 0.4127 - accuracy: 0.8301 - val_loss: 0.3874 - val_accuracy: 0.8388 - 339ms/epoch - 2ms/step
# Epoch 189/200
# 225/225 - 0s - loss: 0.4121 - accuracy: 0.8317 - val_loss: 0.3874 - val_accuracy: 0.8388 - 327ms/epoch - 1ms/step
# Epoch 190/200
# 225/225 - 0s - loss: 0.4130 - accuracy: 0.8314 - val_loss: 0.3883 - val_accuracy: 0.8413 - 354ms/epoch - 2ms/step
# Epoch 191/200
# 225/225 - 0s - loss: 0.4111 - accuracy: 0.8306 - val_loss: 0.3877 - val_accuracy: 0.8388 - 367ms/epoch - 2ms/step
# Epoch 192/200
# 225/225 - 0s - loss: 0.4157 - accuracy: 0.8272 - val_loss: 0.3857 - val_accuracy: 0.8400 - 249ms/epoch - 1ms/step
# Epoch 193/200
# 225/225 - 0s - loss: 0.4105 - accuracy: 0.8304 - val_loss: 0.3861 - val_accuracy: 0.8425 - 250ms/epoch - 1ms/step
# Epoch 194/200
# 225/225 - 0s - loss: 0.4156 - accuracy: 0.8283 - val_loss: 0.3874 - val_accuracy: 0.8388 - 249ms/epoch - 1ms/step
# Epoch 195/200
# 225/225 - 0s - loss: 0.4131 - accuracy: 0.8286 - val_loss: 0.3870 - val_accuracy: 0.8413 - 247ms/epoch - 1ms/step
# Epoch 196/200
# 225/225 - 0s - loss: 0.4101 - accuracy: 0.8311 - val_loss: 0.3869 - val_accuracy: 0.8413 - 243ms/epoch - 1ms/step
# Epoch 197/200
# 225/225 - 0s - loss: 0.4118 - accuracy: 0.8301 - val_loss: 0.3859 - val_accuracy: 0.8400 - 279ms/epoch - 1ms/step
# Epoch 198/200
# 225/225 - 0s - loss: 0.4133 - accuracy: 0.8318 - val_loss: 0.3857 - val_accuracy: 0.8425 - 247ms/epoch - 1ms/step
# Epoch 199/200
# 225/225 - 0s - loss: 0.4128 - accuracy: 0.8294 - val_loss: 0.3859 - val_accuracy: 0.8413 - 248ms/epoch - 1ms/step
# Epoch 200/200
# 225/225 - 0s - loss: 0.4098 - accuracy: 0.8319 - val_loss: 0.3850 - val_accuracy: 0.8438 - 245ms/epoch - 1ms/step

# %%
y_pred = classifier.predict(X_test)
print(y_pred[:5])
# Out:
# 63/63 [==============================] - 0s 805us/step
# [[0.23539424]
#  [0.2967128 ]
#  [0.19062406]
#  [0.09612945]
#  [0.20204754]]

# %%
#Let us use confusion matrix with cutoff value as 0.5
y_pred = (y_pred > 0.5).astype(int)
print(y_pred[:5])
# Out:
# [[0]
#  [0]
#  [0]
#  [0]
#  [0]]

# %%
#Making the Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[1546   49]
#  [ 263  142]]

# %%
#Accuracy of our NN
print(((cm[0][0] + cm[1][1])* 100) / len(y_test), '% of data was classified correctly')
# Out:
# 84.4 % of data was classified correctly
